# %%
import pandas as pd;
ev = pd.read_csv('Electriccar.csv')

# %%
ev
# Out:
#            Brand                               Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla        Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                            ID.3 Pure      10.0           160
# 2      Polestar                           Polestar 2       4.7           210
# 3           BMW                                 iX3        6.8           180
# 4         Honda                                   e        9.5           145
# ..           ...                                 ...       ...           ...
# 164     Peugeot   Peugeot e-Traveller Compact 50 kWh      12.1           130
# 165     Renault                     Renault Zoe R135       9.5           140
# 166      Aiways                    Aiways U5 Premium       7.8           150
# 167        Audi                Audi e-tron S quattro       5.1           210
# 168        Audi     Q4 e-tron 50 quattro S Competion       6.2           180
#
# ...

# %%
ev.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                      Polestar 2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge    PlugType  Seats  \
# 0       450              161             940         Yes  Type 2 CCS      5
# 1       270              167             250         Yes  Type 2 CCS      5
# 2       400              181             620         Yes  Type 2 CCS      5
# 3       360              206             560         Yes  Type 2 CCS      5
# 4       170              168             190         Yes  Type 2 CCS      4
#
#    PriceEuro
# 0      55480
# 1      30000
# 2      56440
# 3      68040
# 4      32997

# %%
ev.shape
# Out:
# (169, 11)

# %%
ev.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm  FastCharge_KmH  \
# count  169.000000    169.000000  169.000000       169.000000      169.000000
# mean     7.569231    178.301775  338.532544       189.195266      463.917160
# std      3.285103     42.612848  124.190619        29.181550      236.152327
# min      2.100000    123.000000   95.000000       104.000000      110.000000
# 25%      5.100000    150.000000  250.000000       168.000000      270.000000
# 50%      7.300000    160.000000  340.000000       181.000000      420.000000
# 75%      9.000000    200.000000  405.000000       206.000000      560.000000
# max     22.400000    410.000000  970.000000       273.000000     1410.000000
#
#             Seats      PriceEuro
# count  169.000000     169.000000
# mean     4.798817   57231.011834
# std      1.026899   34014.571338
# min      2.000000   18500.000000
# 25%      4.000000   35575.000000
# 50%      5.000000   45780.000000
# 75%      5.000000   65000.000000
# ...

# %%
ev.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PlugType           0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
import seaborn as sns #seaborn advance graphics library
sns.set_style('whitegrid')

# %%
import matplotlib.pyplot as plt 
sns.FacetGrid(ev,hue='PriceEuro',height=10).map(plt.scatter,'Range_Km','FastCharge_KmH').add_legend()

# %%
X = ev.drop(columns = ['Brand','Model','RapidCharge','PlugType','PriceEuro'])   #independent variables 
Y = ev['PriceEuro'] # dependent

# %%
X
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats
# 0         4.6           233       450              161             940      5
# 1        10.0           160       270              167             250      5
# 2         4.7           210       400              181             620      5
# 3         6.8           180       360              206             560      5
# 4         9.5           145       170              168             190      4
# ..        ...           ...       ...              ...             ...    ...
# 164      12.1           130       185              243             250      7
# 165       9.5           140       310              168             110      5
# 166       7.8           150       400              167             190      5
# 167       5.1           210       364              267             150      5
# 168       6.2           180       488              180             162      5
#
# [169 rows x 6 columns]

# %%
Y
# Out:
# 0      55480
# 1      30000
# 2      56440
# 3      68040
# 4      32997
#        ...
# 164    50880
# 165    28795
# 166    37990
# 167    52900
# 168    60631
# Name: PriceEuro, Length: 169, dtype: int64

# %%
X_nor = pd.DataFrame(X,columns=['AccelSec','TopSpeed_KmH','Range_Km','Efficiency_WhKm','FastCharge_KmH','Seats'])

# %%
X_nor
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats
# 0         4.6           233       450              161             940      5
# 1        10.0           160       270              167             250      5
# 2         4.7           210       400              181             620      5
# 3         6.8           180       360              206             560      5
# 4         9.5           145       170              168             190      4
# ..        ...           ...       ...              ...             ...    ...
# 164      12.1           130       185              243             250      7
# 165       9.5           140       310              168             110      5
# 166       7.8           150       400              167             190      5
# 167       5.1           210       364              267             150      5
# 168       6.2           180       488              180             162      5
#
# [169 rows x 6 columns]

# %%
X.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm  FastCharge_KmH  \
# count  169.000000    169.000000  169.000000       169.000000      169.000000
# mean     7.569231    178.301775  338.532544       189.195266      463.917160
# std      3.285103     42.612848  124.190619        29.181550      236.152327
# min      2.100000    123.000000   95.000000       104.000000      110.000000
# 25%      5.100000    150.000000  250.000000       168.000000      270.000000
# 50%      7.300000    160.000000  340.000000       181.000000      420.000000
# 75%      9.000000    200.000000  405.000000       206.000000      560.000000
# max     22.400000    410.000000  970.000000       273.000000     1410.000000
#
#             Seats
# count  169.000000
# mean     4.798817
# std      1.026899
# min      2.000000
# 25%      4.000000
# 50%      5.000000
# 75%      5.000000
# max      7.000000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.35,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
lrmodel = LinearRegression()

# %%
lrmodel
# Out:
# LinearRegression()

# %%
lrmodel.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
k_result = lrmodel.predict(X_test)

# %%
k_result
# Out:
# array([ 46465.0737923 ,  27069.9461063 , 109351.15309936,  53541.58548593,
#         55520.66850156,  36037.24566315,  25000.52326735,  68034.90599269,
#         83771.6415327 ,  73512.52908409,  59280.73051728,  49640.72125257,
#         43109.89773053,  47116.56467258,  65076.6566694 ,  60900.44124771,
#         40001.06343346,  41922.48176577,  65601.26070188,  42766.87653225,
#        123606.01884712,  30139.10164634,  78308.52058788,  49622.3098704 ,
#         43330.85590689, 100287.09575968,  49783.28214008,  71692.76481419,
#         95816.16617983,  87195.39266726,  74866.47878582,  24407.2436845 ,
#        102964.68550729,  30730.83488415,  33733.03772132,  74333.8511416 ,
#         64448.51970012,  38034.52574973,  64425.91914258, 103718.4089048 ,
#         35532.75648269,  49929.27372649,  25998.92366448,  25980.73813341,
#         40337.47934064, 221549.71190286,  87452.01342488, 101147.93751616,
# ...

# %%
Y_test
# Out:
# 98      45000
# 44      20129
# 117    191700
# 109     45780
# 62      50000
# 46      41906
# 77      22030
# 13      65000
# 115     69900
# 114     98000
# 153     54000
# 92      36837
# 157     58995
# 89      37500
# 126     65900
# 168     60631
# 166     37990
# 104     32190
# 64      54475
# 127     37995
# 130    140000
# 28      38017
# 67      55000
# 12      40795
# 80      38987
# 72     150000
# 45      36837
# 63      75351
# 47     102945
# 147     97399
# 103     44560
# 74      25500
# 59      96990
# 34      32646
# 20      29146
# 21      58620
# 87      69551
# 96      33133
# 124     43500
# 108     64500
# 29      34361
# 68      38000
# 66      33246
# 55      35921
# 35      37237
# 51     215000
# 107    140000
# 65     109302
# 125     43000
# 138     31600
# 119     50000
# 37      45000
# 121     24790
# 0       55480
# 5      105000
# 11      29234
# 123     38000
# 95      35575
# 49      36057
# 164     50880
# Name: PriceEuro, dtype: int64

# %%
X_test
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats
# 98        7.5           160       330              191             440      5
# 44       12.3           130       195              166             170      4
# 117       2.8           260       390              215             860      2
# 109       8.6           160       420              183             510      5
# 62        7.6           160       440              198             520      5
# 46        7.3           150       335              173             210      5
# 77       12.7           130        95              176             410      4
# 13        4.0           200       450              178             650      5
# 115       3.9           225       450              179             630      4
# 114       4.6           200       505              208             620      7
# 153       6.3           180       330              206             360      4
# ...

# %%
acc = lrmodel.score(X_test,Y_test)

# %%
acc
# Out:
# 0.7839367103415948

# %%
import pickle
pickle.dump(lrmodel,open('EVcar_model','wb'))

# %%
model = pickle.load(open('Evcar_model','rb'))

# %%
result = model.predict(X_test)

# %%
result
# Out:
# array([ 46465.0737923 ,  27069.9461063 , 109351.15309936,  53541.58548593,
#         55520.66850156,  36037.24566315,  25000.52326735,  68034.90599269,
#         83771.6415327 ,  73512.52908409,  59280.73051728,  49640.72125257,
#         43109.89773053,  47116.56467258,  65076.6566694 ,  60900.44124771,
#         40001.06343346,  41922.48176577,  65601.26070188,  42766.87653225,
#        123606.01884712,  30139.10164634,  78308.52058788,  49622.3098704 ,
#         43330.85590689, 100287.09575968,  49783.28214008,  71692.76481419,
#         95816.16617983,  87195.39266726,  74866.47878582,  24407.2436845 ,
#        102964.68550729,  30730.83488415,  33733.03772132,  74333.8511416 ,
#         64448.51970012,  38034.52574973,  64425.91914258, 103718.4089048 ,
#         35532.75648269,  49929.27372649,  25998.92366448,  25980.73813341,
#         40337.47934064, 221549.71190286,  87452.01342488, 101147.93751616,
# ...

# %%
result = model.predict([[4.5,210,350,180,550,5]])

# %%
result
# Out:
# array([67795.0907565])
